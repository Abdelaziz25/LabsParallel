# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# Function to calculate scaled efficiency
def scaled_efficiency(p, delta, f):
    return (f + (1 - f) * p ** delta) / (p * f + (1 - f) * p ** delta)

# Function to create a meshgrid
def create_meshgrid(start, end, num_points):
    return np.linspace(start, end, num_points)

# Function to plot a 3D surface
def plot_3d_surface(ax, p, delta, scaled_eff):
    ax.plot_wireframe(p, delta, scaled_eff, color='blue', rstride=10, cstride=10)

# Function to plot contour lines
def plot_contour_lines(ax, p, delta, scaled_eff, levels):
    contour = ax.contour(p, delta, scaled_eff, levels=levels, offset=0, cmap='coolwarm')
    ax.clabel(contour, contour.levels, inline=True, fontsize=10)

# Function to set labels and title for the plot
def set_labels_and_title(ax):
    ax.set_xlabel('Number of Processing Units P')
    ax.set_ylabel('Delta δ')
    ax.set_zlabel('Scaled Efficiency  Eγ(p)')
    ax.set_title('Functional Dependency of Scaled Efficiency')

# Function to set axis limits and ticks
def set_axis_limits_and_ticks(ax):
    ax.set_zlim(0, 1)
    ax.set_zticks(np.arange(0, 1.2, 0.2))
    ax.set_xlim(0, 20)
    ax.set_xticks(np.arange(0, 21, 5))

# Function to customize the plot (view angle and distance)
def customize_plot(ax):
    ax.view_init(elev=25, azim=-60)
    ax.dist = 12

# Generate meshgrid values for P and delta
p_values = create_meshgrid(1, 20, 100)
delta_values = create_meshgrid(0, 1, 100)
p, delta = np.meshgrid(p_values, delta_values)

# Set a constant value for f
f = 0.1

# Calculate scaled efficiency values
scaled_eff = scaled_efficiency(p, delta, f)

# Create a 3D plot
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')

# Plot the 3D surface
plot_3d_surface(ax, p, delta, scaled_eff)

# Specify more contour levels for efficiency
efficiency_levels = np.linspace(0, 1, 11)  # 11 contour lines from 0 to 1

# Plot contour lines
plot_contour_lines(ax, p, delta, scaled_eff, efficiency_levels)

# Set labels, title, axis limits, and ticks
set_labels_and_title(ax)
set_axis_limits_and_ticks(ax)

# Customize the plot
customize_plot(ax)

# Display the plot
plt.show()
# Out:
# <ipython-input-7-015dae815b22>:39: MatplotlibDeprecationWarning: The dist attribute was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   ax.dist = 12
